# %% [markdown]
# [Data in Kaggle](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results?select=athlete_events.csv)

# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the data

# %%
df=pd.read_csv("/content/athlete_events.csv")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
# insights
# missing values in
# Age                  9474
# Height              60171
# Weight              62875
# Medal              231333

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df[df.duplicated()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1252       704                   Dsir Antoine Acket   M  27.0     NaN     NaN
# 4282      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4283      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4862      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# 4864      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0     NaN     NaN
# 270200  135173                     Henri Achille Zo   M  58.0     NaN     NaN
#
# ...

# %%
# player can participate in the same game during the same year

# %% [markdown]
# ### Don't forget to drop duplicates first

# %%
df.duplicated().sum()
# Out:
# 1385

# %%
# Game column is duplicate to both columns year and season

# %%
df1=df.copy()
df1.drop(columns=['Games','ID'],inplace=True,axis=1)
df1.head()
# Out:
#                        Name Sex   Age  Height  Weight            Team  NOC  \
# 0                 A Dijiang   M  24.0   180.0    80.0           China  CHN
# 1                  A Lamusi   M  23.0   170.0    60.0           China  CHN
# 2       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark  DEN
# 3      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 4  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands  NED
#
#    Year  Season       City          Sport                             Event  \
# 0  1992  Summer  Barcelona     Basketball       Basketball Men's Basketball
# 1  2012  Summer     London           Judo      Judo Men's Extra-Lightweight
# 2  1920  Summer  Antwerpen       Football           Football Men's Football
# 3  1900  Summer      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War
# 4  1988  Winter    Calgary  Speed Skating  Speed Skating Women's 500 metres
#
#   Medal
# 0   NaN
# 1   NaN
# 2   NaN
# 3  Gold
# 4   NaN

# %% [markdown]
# # <font color='red'>**Beginner level**</font>

# %% [markdown]
# ### Find the missing data in each column

# %%
df1.isnull().sum()
# Out:
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# ### Number of males and females

# %%
(df1['Sex']=='M').sum()
# Out:
# 196594

# %%
(df1['Sex']=='F').sum()
# Out:
# 74522

# %% [markdown]
# ### How many cities do we have and what are they ?

# %%
df1['City'].unique()
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Calgary',
#        'Albertville', 'Lillehammer', 'Los Angeles', 'Salt Lake City',
#        'Helsinki', 'Lake Placid', 'Sydney', 'Atlanta', 'Stockholm',
#        'Sochi', 'Nagano', 'Torino', 'Beijing', 'Rio de Janeiro', 'Athina',
#        'Squaw Valley', 'Innsbruck', 'Sarajevo', 'Mexico City', 'Munich',
#        'Seoul', 'Berlin', 'Oslo', "Cortina d'Ampezzo", 'Melbourne',
#        'Roma', 'Amsterdam', 'Montreal', 'Moskva', 'Tokyo', 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'St. Louis', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %%
print(len(df1['City'].unique()))
# Out:
# 42

# %%
df_numerical_features = df1.select_dtypes(include='number')
df_numerical_features.columns
# Out:
# Index(['Age', 'Height', 'Weight', 'Year'], dtype='object')

# %%
df_numerical_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Age     261642 non-null  float64
#  1   Height  210945 non-null  float64
#  2   Weight  208241 non-null  float64
#  3   Year    271116 non-null  int64
# dtypes: float64(3), int64(1)
# memory usage: 8.3 MB

# %%
df_categorical_features = df1.select_dtypes(include='object')
df_categorical_features.columns
# Out:
# Index(['Name', 'Sex', 'Team', 'NOC', 'Season', 'City', 'Sport', 'Event',
#        'Medal'],
#       dtype='object')

# %%
df_categorical_features['Team'].unique()
print(len(df_categorical_features['Team'].unique()))
# Out:
# 1184

# %%
df_categorical_features['Team'].value_counts()
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Briar                1
# Hannover             1
# Nan-2                1
# Brentina             1
# Digby                1
# Name: Team, Length: 1184, dtype: int64

# %%
team_counts = df_categorical_features['Team'].value_counts()

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart
axes[0].pie(team_counts, labels=team_counts.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Teams Distribution (Pie Chart)')

# Bar chart
team_counts.plot(kind='bar', ax=axes[1])
axes[1].set_title('Teams Distribution (Bar Chart)')
axes[1].set_ylabel('Count')
axes[1].set_xlabel('Team')

plt.tight_layout()
plt.show()

# %%
df_categorical_features['NOC'].unique()
print(len(df_categorical_features['NOC'].unique()))
# Out:
# 230

# %%
df_categorical_features['NOC'].value_counts()
# Out:
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
#        ...
# YMD        5
# SSD        3
# UNK        2
# NBO        2
# NFL        1
# Name: NOC, Length: 230, dtype: int64

# %%
noc = df_categorical_features['NOC'].value_counts()

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart
axes[0].pie(noc, labels=noc.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('NOC Distribution (Pie Chart)')

# Bar chart
noc.plot(kind='bar', ax=axes[1])
axes[1].set_title('NOC Distribution (Bar Chart)')
axes[1].set_ylabel('Count')
axes[1].set_xlabel('NOC')

plt.tight_layout()
plt.show()

# %%
df_categorical_features['Sport'].unique()
print(len(df_categorical_features['Sport'].unique()))
# Out:
# 66

# %%
df_categorical_features['Sport'].value_counts()
# Out:
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: Sport, Length: 66, dtype: int64

# %%
sports = df_categorical_features['Sport'].value_counts()

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart
axes[0].pie(sports, labels=sports.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Sport Distribution (Pie Chart)')

# Bar chart
sports.plot(kind='bar', ax=axes[1])
axes[1].set_title('Sport Distribution (Bar Chart)')
axes[1].set_ylabel('Count')
axes[1].set_xlabel('Sport')

plt.tight_layout()
plt.show()

# %%
df_categorical_features['Medal'].unique()
print(len(df_categorical_features['Medal'].unique()))
# Out:
# 4

# %%
df_categorical_features['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
medals = df_categorical_features['Medal'].value_counts()

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart
axes[0].pie(medals, labels=medals.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Medal Distribution (Pie Chart)')

# Bar chart
medals.plot(kind='bar', ax=axes[1])
axes[1].set_title('Medal Distribution (Bar Chart)')
axes[1].set_ylabel('Count')
axes[1].set_xlabel('Medal')

plt.tight_layout()
plt.show()

# %%
df1['Year'] = df['Year'].astype(str)

# %%
df1['Year'].unique()
print(len(df1['Year'].unique()))
# Out:
# 35

# %%
df1['Year'].value_counts()
# Out:
# 1992    16413
# 1988    14676
# 2000    13821
# 1996    13780
# 2016    13688
# 2008    13602
# 2004    13443
# 2012    12920
# 1972    11959
# 1984    11588
# 1976    10502
# 1968    10479
# 1964     9480
# 1952     9358
# 1960     9235
# 1980     8937
# 1948     7480
# 1936     7401
# 1956     6434
# 1924     5693
# 1928     5574
# 2014     4891
# 2010     4402
# 2006     4382
# 1920     4292
# 2002     4109
# 1912     4040
# 1998     3605
# 1932     3321
# 1994     3160
# 1908     3101
# 1900     1936
# 1906     1733
# 1904     1301
# 1896      380
# Name: Year, dtype: int64

# %%
year = df1['Year'].value_counts()

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart
axes[0].pie(year, labels=year.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Year Distribution (Pie Chart)')

# Bar chart
year.plot(kind='bar', ax=axes[1])
axes[1].set_title('Year Distribution (Bar Chart)')
axes[1].set_ylabel('Count')
axes[1].set_xlabel('Year')

plt.tight_layout()
plt.show()

# %%
df_numerical_features.columns
# Out:
# Index(['Age', 'Height', 'Weight', 'Year'], dtype='object')

# %%
# Sample data creation
np.random.seed(0)

# Plotting Histogram with KDE and Boxplot for each numerical feature
fig, axes = plt.subplots(len(df_numerical_features.columns), 2, figsize=(12, 5 * len(df_numerical_features.columns)))

for i, col in enumerate(df_numerical_features.columns):
    # Histogram with KDE
    df_numerical_features[col].plot(kind='hist', density=True, ax=axes[i, 0], bins=20, alpha=0.5, color='blue')
    df_numerical_features[col].plot(kind='kde', ax=axes[i, 0], color='red')
    axes[i, 0].set_title(f'{col} - Histogram with KDE')

    # Boxplot
    df_numerical_features.boxplot(column=col, ax=axes[i, 1])
    axes[i, 1].set_title(f'{col} - Boxplot')

plt.tight_layout()
plt.show()

# %% [markdown]
# # <font color='red'>**Intermediate level**</fond>

# %%
df1.columns
# Out:
# Index(['Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Year',
#        'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# ### Find the number of athlete for each year

# %%
athlete_count = df1.groupby('Year')['Name'].nunique()
athlete_count .reset_index(name="count of athlete")
# Out:
#     Year  count of athlete
# 0   1896               176
# 1   1900              1220
# 2   1904               650
# 3   1906               841
# 4   1908              2024
# 5   1912              2409
# 6   1920              2675
# 7   1924              3565
# 8   1928              3702
# 9   1932              2174
# 10  1936              5138
# 11  1948              5068
# 12  1952              5621
# 13  1956              4166
# 14  1960              6012
# 15  1964              6226
# 16  1968              6711
# 17  1972              8111
# 18  1976              7194
# 19  1980              6323
# 20  1984              8057
# 21  1988              9860
# 22  1992             11172
# 23  1994              1738
# 24  1996             10324
# 25  1998              2178
# 26  2000             10639
# 27  2002              2397
# 28  2004             10537
# 29  2006              2494
# 30  2008             10880
# 31  2010              2535
# 32  2012             10502
# ...

# %% [markdown]
# ### Which athlete participated the most? (his/her name and ID)

# %%
most_participated_athlete = df1['Name'].value_counts()
print( most_participated_athlete)
# Out:
# Robert Tait McKenzie            58
# Heikki Ilmari Savolainen        39
# Joseph "Josy" Stoffel           38
# Ioannis Theofilakis             36
# Takashi Ono                     33
#                                 ..
# Tatyana Vasilyevna Kalmykova     1
# Mariya Lvovna Kalmykova          1
# Christine Kalmer                 1
# Joannis "Jannis" Kalmazidis      1
# Pierre-Georges LeClercq          1
# Name: Name, Length: 134732, dtype: int64

# %%
most_participated_athlete.idxmax()
# Out:
# 'Robert Tait McKenzie'

# %% [markdown]
# # <font color='red'>**Advanced level**</fond>

# %% [markdown]
# ### Find the number of each medal for each year.
# ##### The output should look like this
# ![Capture.PNG](data:image/png;base64,...)

# %%
medal_counts = df1.groupby(['Year', 'Medal']).size()
print(medal_counts)
# Out:
# Year  Medal
# 1896  Bronze     38
#       Gold       62
#       Silver     43
# 1900  Bronze    175
#       Gold      201
#                ...
# 2014  Gold      202
#       Silver    197
# 2016  Bronze    703
#       Gold      665
#       Silver    655
# Length: 105, dtype: int64

# %%
medal_counts.unstack(fill_value=0).reset_index()
# Out:
# Medal  Year  Bronze  Gold  Silver
# 0      1896      38    62      43
# 1      1900     175   201     228
# 2      1904     150   173     163
# 3      1906     145   157     156
# 4      1908     256   294     281
# 5      1912     300   326     315
# 6      1920     367   493     448
# 7      1924     311   332     319
# 8      1928     281   275     267
# 9      1932     232   261     246
# 10     1936     330   348     347
# 11     1948     325   330     332
# 12     1952     347   351     335
# 13     1956     348   353     342
# 14     1960     357   359     342
# 15     1964     401   408     406
# 16     1968     421   425     410
# 17     1972     485   474     455
# 18     1976     518   508     505
# 19     1980     542   529     531
# 20     1984     576   571     551
# 21     1988     637   607     601
# 22     1992     710   663     657
# 23     1994     112   110     109
# 24     1996     629   608     605
# 25     1998     150   145     145
# ...

# %% [markdown]
# # <font color='red'>**You are Geek!**</fond>
# ### Provide all your answers with plots

# %%
#  dense plot it's meaningless *_*

# athlete for each year

# %%
# Plotting

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart
axes[0].pie(athlete_count, labels=athlete_count.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Percentage of Athletes by Year')
# Bar chart
athlete_count.plot(kind='bar',ax=axes[1])
axes[1].set_title('Count of Athletes Over the Years')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Count of Athletes')
plt.show()

# %%
#  number of each medal for each year.

# %%
# Plotting

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Pie chart
axes[0].pie(medal_counts, labels=medal_counts.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('medal_counts by Year')
# Bar chart
medal_counts.plot(kind='bar',ax=axes[1])
axes[1].set_title('Count of medal Over the Years')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Count of medal')
plt.show()

# %% [markdown]
# ### Find the number of winners with the gold medal in each city?

# %%
number_of_winners_with_the_gold_medal= df1[df1['Medal'] == 'Gold']
print( number_of_winners_with_the_gold_medal)
# Out:
#                                        Name Sex   Age  Height  Weight  \
# 3                      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48                  Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60                       Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...                                     ...  ..   ...     ...     ...
# 270981                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009                          Julia Zwehl   F  28.0   167.0    60.0
# 271016       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
#                   Team  NOC  Year  Season         City          Sport  \
# ...

# %%
number_of_winners_with_the_gold_medal=number_of_winners_with_the_gold_medal.groupby('City').size()
number_of_winners_with_the_gold_medal.reset_index(name=' count of golden medal')
# Out:
#                       City   count of golden medal
# 0              Albertville                     104
# 1                Amsterdam                     245
# 2                Antwerpen                     493
# 3                   Athina                     883
# 4                  Atlanta                     608
# 5                Barcelona                     559
# 6                  Beijing                     671
# 7                   Berlin                     312
# 8                  Calgary                      87
# 9                 Chamonix                      55
# 10       Cortina d'Ampezzo                      51
# 11  Garmisch-Partenkirchen                      36
# 12                Grenoble                      66
# 13                Helsinki                     306
# 14               Innsbruck                     131
# 15             Lake Placid                     104
# 16             Lillehammer                     110
# ...

# %% [markdown]
# ### Find the total missing data for each year?

# %%
df2=df1.groupby('Year').apply(lambda x: x.isnull().sum())
print (df2)
# Out:
#       Name  Sex   Age  Height  Weight  Team  NOC  Year  Season  City  Sport  \
# Year
# 1896     0    0   163     334     331     0    0     0       0     0      0
# 1900     0    0   790    1820    1857     0    0     0       0     0      0
# 1904     0    0   274    1088    1154     0    0     0       0     0      0
# 1906     0    0   743    1476    1528     0    0     0       0     0      0
# 1908     0    0   649    2626    2618     0    0     0       0     0      0
# 1912     0    0   156    3319    3444     0    0     0       0     0      0
# 1920     0    0   845    3525    3821     0    0     0       0     0      0
# 1924     0    0  1142    4719    5003     0    0     0       0     0      0
# 1928     0    0   963    4599    4856     0    0     0       0     0      0
# 1932     0    0   330    2108    2771     0    0     0       0     0      0
# 1936     0    0   213    6209    6414     0    0     0       0     0      0
# ...

# %%
len(df2)
# Out:
# 35

# %% [markdown]
# # <font color='red'>**I dare you to solve this :)**</fond>
# ### Dont use for loops, and provide all your answers with plots.

# %% [markdown]
# ### Has the number of athletes changed over time for Summer and Winter?

# %%
df1.groupby(['Name', 'Season']).size()
# Out:
# Name                                       Season
#   Gabrielle Marie "Gabby" Adcock (White-)  Summer    1
#  Eleonora Margarida Josephina Scmitt       Summer    2
#  Jean Hauptmanns                           Summer    1
#  Luis ngel Fernando de los Santos Grossi   Summer    5
#  Th Anh                                    Summer    1
#                                                     ..
# zge Krdar emberci                          Summer    1
# zlem Kaya                                  Summer    2
# zman Graud                                 Summer    1
# zzet Safer                                 Summer    1
# zzet nce                                   Summer    2
# Length: 135045, dtype: int64
